# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = "latin-1")

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df1=df.groupby('Area')

# %%
df1.first()['Y2017'].sort_values()
# Out:
# Area
# Sudan (former)                      0.00
# Comoros                             0.00
# Ethiopia PDR                        0.00
# Seychelles                          0.57
# Sao Tome and Principe             207.00
# Cabo Verde                        537.00
# Djibouti                          944.00
# Eswatini                         1125.00
# Mauritius                        1264.00
# Guinea-Bissau                    1828.00
# Gabon                            2065.00
# Lesotho                          2092.00
# Botswana                         2205.00
# Gambia                           2214.00
# Namibia                          2403.00
# Mauritania                       4283.00
# Central African Republic         4596.00
# Liberia                          4702.00
# Congo                            5111.00
# Sierra Leone                     7488.00
# Togo                             7698.00
# Benin                           11175.00
# Tunisia                         11433.00
# ...

# %%
df2=df.groupby('Element')

# %%
df2.first()[['Y2014','Y2015','Y2016','Y2017']].max()
# Out:
# Y2014    38924.0
# Y2015    39728.0
# Y2016    40551.0
# Y2017    41389.0
# dtype: float64

# %%
df[(df['Area']=='Madagascar') & (df['Element']=='Protein supply quantity (g/capita/day)')]['Y2015'].sum()
# Out:
# 173.04999999999998

# %%
df.mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4588\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Area Code        134.265576
# Item Code       2687.176706
# Element Code    3814.856456
# Y2014            134.196282
# Y2015            135.235966
# Y2016            136.555222
# Y2017            140.917765
# Y2018            143.758381
# dtype: float64

# %%
df3=df.groupby('Element Code')

# %%
df.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
df.iloc(1)

# %%
df['Area'].nunique()
# Out:
# 49

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

# %%
col = ['Age','Nationality','Overall']
# Out:
#   Input In [79]
#     col = [‘Age’,’Nationality’,’Overall’]
#            ^
# SyntaxError: invalid character '‘' (U+2018)

# %%
len(df['Y2014'].dropna()) - len(df['Y2014'])
# Out:
# -1589
